# %%
import pandas as pd
import numpy as np
import panel as pn
pn.extension('tabulator')

import hvplot.pandas
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='46781791-fd9c-40a1-b3be-e85d04fe915b'>
#   <div id="e3959385-8d6c-45f7-937b-b915ed2345ed" data-root-id="46781791-fd9c-40a1-b3be-e85d04fe915b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"8914652a-d054-4717-bdbc-3745064f0f1b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"46781791-fd9c-40a1-b3be-e85d04fe915b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"5a32991e-e9af-439e-bf8d-877bf1c25cc6","attributes":{"plot_id":"46781791-fd9c-40a1-b3be-e85d04fe915b","comm_id":"f32525d2466049f19a84ed35bc057e69","client_comm_id":"4a4f96c394cf4494af68b2ffc2821249"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"8914652a-d054-4717-bdbc-3745064f0f1b","roots":{"46781791-fd9c-40a1-b3be-e85d04fe915b":"e3959385-8d6c-45f7-937b-b915ed2345ed"},"root_ids":["46781791-fd9c-40a1-b3be-e85d04fe915b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owidiu/Romanian-agricultural-data-analysis/main/datasets/main-crops.csv')

# %%
df
# Out:
#               county  year  cultivated_area  harvested_area   wheat   rye  \
# 0              BIHOR  2015           281006          281006  332807  1408
# 1    BISTRITA_NASAUD  2015            62773           62773    9612    69
# 2               CLUJ  2015           106644          106093   39342   584
# 3          MARAMURES  2015            65794           65609    9781    20
# 4          SATU_MARE  2015           192825          192774  159479   559
# ..               ...   ...              ...             ...     ...   ...
# 331           VALCEA  2022            62741           62699   25812     0
# 332             ARAD  2022           255137          254346  362768   327
# 333    CARAS_SEVERIN  2022            63887           63625   64877     0
# 334        HUNEDOARA  2022            48902           48820   32449   500
# 335            TIMIS  2022           394288          392500  742402  1127
#
#      barley    oat    corn  triticale  ...  grapes  wine_grapes  table_grapes  \
# 0     65033  24527  294172        431  ...   14955        14568           387
# 1      5982   4490   60454        786  ...    1447         1405            42
# 2     36975  10568  132149       1813  ...    1020         1020             0
# 3      1417   5678   51217       7095  ...     958          958             0
# 4     17792  13652  266963      34915  ...   13941        13828           113
# ..      ...    ...     ...        ...  ...     ...          ...           ...
# 331    2563   3666  149291       1781  ...   26092        25227           865
# 332   39707   8099  227256       9073  ...   11351        10586           765
# 333    7797   1128   65393       3737  ...    2542         2542             0
# 334    2891   1340   72731       2887  ...       0            0             0
# 335   71282   5800  247239      12384  ...   24168        23118          1050
#
#      apple  pear   plum  apricot  cherry  peach  nuts
# 0    15071  2095  15622     1573    1703   7766   850
# 1    33013  1212  10592        8    1993      9   803
# 2     7017   932   9635      248     649     83   493
# 3    42657  1476  11318       38    2323    150  1890
# 4    15711   901  18784      537    2298    900  1267
# ..     ...   ...    ...      ...     ...    ...   ...
# 331  29196  2234  59822      838    1546    119  2653
# 332   7458   470   8109      286     810    462  1015
# 333  11878   648  32325      223    1089    266  1214
# 334   8470  1040  22210      171     907    228  1803
# 335   5694   719  14913      668    1407   1454  1004
#
# [336 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['county', 'year', 'cultivated_area', 'harvested_area', 'wheat', 'rye',
#        'barley', 'oat', 'corn', 'triticale', 'peas_beans', 'beans', 'potato',
#        'sugar_beet', 'fodder_beet', 'rapeseed', 'sunflower', 'soy_beans',
#        'cabbage', 'cauliflower_broccoli', 'tomatoes', 'cucumber',
#        'watermelons', 'eggplant', 'pepper', 'carrot', 'garlic', 'onion',
#        'green_peas', 'green_beans', 'green_fodder', 'perennial_fodder',
#        'grapes', 'wine_grapes', 'table_grapes', 'apple', 'pear', 'plum',
#        'apricot', 'cherry', 'peach', 'nuts'],
#       dtype='object')

# %%
df[df['county'] == 'PRAHOVA']
# Out:
#       county  year  cultivated_area  harvested_area   wheat  rye  barley  \
# 31   PRAHOVA  2015           140109          139402  136743  286   20192
# 73   PRAHOVA  2016           142824          142273  157447   77   25565
# 115  PRAHOVA  2017           142118          141702  152335    0   19938
# 157  PRAHOVA  2018           142403          141125  128080    0   15364
# 199  PRAHOVA  2019           142960          141819  182654    0   31422
# 241  PRAHOVA  2020           150275          148846   93281    0   13962
# 283  PRAHOVA  2021           136384          135948  159230    0   24187
# 325  PRAHOVA  2022           139294          138945  146429    0   21975
#
#       oat    corn  triticale  ...  grapes  wine_grapes  table_grapes  apple  \
# 31   1142  185874       2290  ...   35282        34716           566  14366
# 73   1506  209229       1800  ...   28327        27838           489  10966
# 115  1038  287216       1197  ...   45463        44488           975   7801
# 157   858  325727        554  ...   46980        45717          1263  30041
# 199  1467  290357       2292  ...   34364        33369           995  19340
# 241  1027  219598       1246  ...   41321        40335           986  18085
# 283   922  243413       2321  ...   45442        44708           734  19565
# 325   797  177585       1234  ...   33637        32861           776  18263
#
#      pear   plum  apricot  cherry  peach  nuts
# 31   2434  21312     1186    2320    498  1297
# 73   2751  27780     1306    2308    673  1367
# 115  2256  18010     1373    1901    713  1745
# 157  2766  50207     1462    3086    747  2202
# 199  2361  44066     1231    2786    558  2141
# 241  2430  61190     1176    3236    495  2303
# 283  2443  61322     1254    2982    490  2132
# 325  1922  44152     1087    2287    457  2023
#
# [8 rows x 42 columns]

# %%
idf = df.interactive()

# %%
year_slider = pn.widgets.IntSlider(name='Year slider', start=2016, end=2022, step=1, value=2016)
year_slider
# Out:
# IntSlider(end=2022, name='Year slider', start=2016, value=2016)

# %%
# Radio buttons for cultivated_area and harvested_area

yaxis_area = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['cultivated_area', 'harvested_area',],
    button_type = 'success'
)

# %%
counties = ['BUZAU', 'GALATI', 'CONSTANTA', 'BRAILA', 'CALARASI', 'TULCEA', 'IALOMITA', 'OLT']
area_pipeline = (
    idf[
        (idf.year <= year_slider) &
        (idf.county.isin(counties))
    ]
    .groupby(['county', 'year'])[yaxis_area].mean()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
area_plot = area_pipeline.hvplot(x = 'year', by = 'county', y=yaxis_area, line_width=2, title="Area by county")
area_plot
# Out:
# <div id='297ea5e2-5ac2-4718-9f0e-20fcafda01db'>
#   <div id="db69fc46-b5f6-4a27-b8a0-b0f1bbf389c8" data-root-id="297ea5e2-5ac2-4718-9f0e-20fcafda01db" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"c8082875-6c11-4578-83ef-304090cf4e56":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"297ea5e2-5ac2-4718-9f0e-20fcafda01db","attributes":{"name":"Row02813","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"5e54d26a-f4ec-4ce7-9eda-be6ff1267dc1","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3c84e080-e09d-43bd-ba4b-5ea3451f9487","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a783b8ee-b56b-43dc-88a5-f38d022ffaf0","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"417c8233-d3e0-4b00-aedf-2278d5f16281","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"36db9be4-7aca-4f9c-9c4d-fd4eff4d609c","attributes":{"name":"Column02812","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"5e54d26a-f4ec-4ce7-9eda-be6ff1267dc1"},{"id":"3c84e080-e09d-43bd-ba4b-5ea3451f9487"},{"id":"a783b8ee-b56b-43dc-88a5-f38d022ffaf0"},{"id":"417c8233-d3e0-4b00-aedf-2278d5f16281"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":
}],"margin":[5,10],"align":"start","text":"&lt;table class=&quot;dataframe p ...

# %%
harvested_vs_wheat_scatterplot = harvested_vs_wheat_scatterplot_pipeline.hvplot(x='wheat', y='harvested_area', by='county', size=80, kind="scatter", alpha=0.7, legend=False, height=500, width=500)
harvested_vs_wheat_scatterplot
# Out:
# <div id='b3b6262e-c478-43ed-bbf3-c0cb23cefbc9'>
#   <div id="c30e5f7c-01d8-41b1-9ad3-ee57e55b177d" data-root-id="b3b6262e-c478-43ed-bbf3-c0cb23cefbc9" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"970a074e-eb12-4022-bc69-1ca0d37de19a":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"b3b6262e-c478-43ed-bbf3-c0cb23cefbc9","attributes":{"name":"Row05569","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"7cdd3e75-dad7-4142-90fe-dbffea639941","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"449e7678-0748-419e-8ea6-b11fef1783db","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"1d47b835-4b3d-4f27-b7c6-f2e3f53aeaca","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"eeb1b456-a9c2-444f-b512-028a801ff7b8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"66063c39-246c-4176-8b6a-c506bd845bad","attributes":{"name":"Column05568","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7cdd3e75-dad7-4142-90fe-dbffea639941"},{"id":"449e7678-0748-419e-8ea6-b11fef1783db"},{"id":"1d47b835-4b3d-4f27-b7c6-f2e3f53aeaca"},{"id":"eeb1b456-a9c2-444f-b512-028a801ff7b8"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"f1a1d8ca-9f0c-4edb-84cb-ed7a21e246f5","attributes":{"name":"Column05559","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7cdd3e75-dad7-4142-90fe-dbffea639941"},{"id":"449e7678-0748-419e-8ea6-b11fef1783db"},{"id":"1d47b835-4b3d-4f27-b7c6-f2e3f53aeaca"},{"id":"eeb1b456-a9c2-444f-b512-028a801ff7b8"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"7d1ba544-677d-4d8b-ac5c-c0790e630a17","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"7cdd3e75-dad7-4142-90fe-dbffea639941"},{"id":"1d47b835-4b3d-4f27-b7c6-f2e3f53aeaca"},{"id":"eeb1b456-a9c2-444f-b512-028a801ff7b8"}],"margin":[5,10],"align":"start","title":"Year slider","start":2016,"end":2022,"value":2016}}]}},{"type":"object","name":"Figure","id":"74b47841-41dc-4ebd-a548-837f2fad7147","attributes":{"width":500,"height":500,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"04e7a6a2-276c-4bac-b30b-4ab20b141a90","attributes":{"tags":[[["wheat","wheat",null]],[]],"start":-66382.7,"end":730209.7,"reset_start":-66382.7,"reset_end":730209.7}},"y_range":{"type":"object","name":"Range1d","id":"5b25b024-4604-4220-81f9-3565a42986c3","attributes":{"tags":[[["harvested_area","harvested_area",null]],{"type":"map","entries":[["invert_yaxis",false],["autorange",false]]}],"start":-49214.600000000006,"end":542008.6,"reset_start":-49214.600000000006,"reset_end":542008.6}},"x_scale":{"type":"object","name":"LinearScale","id":"aa33c91d-643c-462e-a46a-742590cbd8bb"},"y_scale":{"type":"object","name":"LinearScale","id":"44048e67-8405-4f1c-9293-858e7ec8c702"},"title":{"type":"object","name":"Title","id":"0eda7abd-b4a1-4e1c-9f12-bda6e46bd427","attributes":{"text_color":"black","text_font_size":"12pt"}},"renderers":[{"type":"object","name":"GlyphRenderer","id":"29fcac93-72a1-4b57-8265-707299a45d18","attributes":{"data_source":{"type":"object","name":"ColumnDataSource","id":"9f42fc24-c172-46d ...

# %%
yaxis_crop_source = pn.widgets.RadioButtonGroup(
    name='Y axis',
    options=['wheat', 'rye', 'grapes', 'nuts', 'eggplant', 'tomatoes'],
    button_type='success'
)

counties_excl_ro = ['PRAHOVA', 'ILFOV', 'BRASOV', 'TIMIS', 'BRASOV']

crop_source_pipeline = (
    idf[
        (idf.year == year_slider) &
        (idf.county.isin(counties_excl_ro))
    ]
    .groupby(['year', 'county'])[yaxis_crop_source].sum()
    .to_frame()
    .reset_index()
    .sort_values(by='year')
    .reset_index(drop=True)
)

# %%
crop_source_plot = crop_source_pipeline.hvplot(kind='bar', x='county', y=yaxis_crop_source, title='Main crops production by county')
crop_source_plot
# Out:
# <div id='08d63f70-8d3c-46f4-824e-aad6267f8e99'>
#   <div id="b4c31975-ba17-4892-be67-11e05cee2eaf" data-root-id="08d63f70-8d3c-46f4-824e-aad6267f8e99" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"a5602b58-6670-4078-8f9b-5f121ea71f81":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"08d63f70-8d3c-46f4-824e-aad6267f8e99","attributes":{"name":"Row07748","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"d242a6bb-06cb-4bc5-9187-96974e7677fb","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"87851d4f-5ca7-4ebf-bc40-e4af34351684","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"a0cf0b78-dbae-4428-81c4-6cebb7080b29","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"f3833a7f-c554-48a1-b838-7caf5f622059","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"18f0d6fd-4464-494a-a1ec-11ad2a3b9591","attributes":{"name":"Column07747","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d242a6bb-06cb-4bc5-9187-96974e7677fb"},{"id":"87851d4f-5ca7-4ebf-bc40-e4af34351684"},{"id":"a0cf0b78-dbae-4428-81c4-6cebb7080b29"},{"id":"f3833a7f-c554-48a1-b838-7caf5f622059"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"cec32577-9bbb-44a0-9702-9e755ef41ef7","attributes":{"name":"Column07738","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d242a6bb-06cb-4bc5-9187-96974e7677fb"},{"id":"87851d4f-5ca7-4ebf-bc40-e4af34351684"},{"id":"a0cf0b78-dbae-4428-81c4-6cebb7080b29"},{"id":"f3833a7f-c554-48a1-b838-7caf5f622059"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"582956cf-01a3-4617-ab56-e8ebb8b533cf","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d242a6bb-06cb-4bc5-9187-96974e7677fb"},{"id":"a0cf0b78-dbae-4428-81c4-6cebb7080b29"},{"id":"f3833a7f-c554-48a1-b838-7caf5f622059"}],"margin":[5,10],"align":"start","title":"Year slider","start":2016,"end":2022,"value":2016}},{"type":"object","name":"panel.models.widgets.RadioButtonGroup","id":"5ef5b544-f40c-4742-aa88-041ad685527a","attributes":{"button_type":"success","css_classes":["solid"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"d242a6bb-06cb-4bc5-9187-96974e7677fb"},{"type":"object","name":"ImportedStyleSheet","id":"6fff5d1d-8954-493f-9818-5b70110880a8","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.2/dist/css/button.css"}},{"id":"a0cf0b78-dbae-4428-81c4-6cebb7080b29"},{"id":"f3833a7f-c554-48a1-b838-7caf5f622059"}],"margin":[5,10],"align":"start","labels":["wheat","rye","grapes","nuts","eggplant","tomatoes"],"active":0}}]}},{"type":"object","name":"Figure","id":"606e6ceb-4022-4226-a41f-eb748a510ee2","attributes":{"width":700,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"FactorRange","id":"483a13a8-8a85-465d-a30d-c67db8e08fc5","attributes":{"tags":[[["county","county",null]],[]],"factors":["BRASOV","ILFOV","PRAHOVA","TIMIS"]}},"y_range":{"type":"object","name":"Range1d","id":"f8dd9ca8-087e-4751-bcf2-224d3ec2d3f2","at ...

# %%
#Template layout

template = pn.template.FastListTemplate(
    title='Romania main crop analysis dashboard', 
    sidebar=[pn.pane.Markdown("# Project description"), 
             pn.pane.Markdown("#### This project aims to analyze the main agricultural crops cultivated in Romania from 2015 to 2022. By examining agricultural datasets spanning these years, the project seeks to uncover insights into cultivation and harvest trends for key crops. Through statistical analysis and visualization, the project aims to provide a clear understanding of regional variations, crop diversification, and yield fluctuations over time."), 
             pn.pane.Markdown("## Settings"),   
             year_slider],
    main=[pn.Row(pn.Column(yaxis_area, 
                           area_plot.panel(width=600), margin=(0,20)), 
                 area_table.panel(width=600)), 
          pn.Row(pn.Column(harvested_vs_wheat_scatterplot.panel(width=600), margin=(0,20)), 
                 pn.Column(yaxis_crop_source, crop_source_plot.panel(width=600)))],
    accent_base_color="#c6df86",
    header_background="#477594",
)
# template.show()
template.servable();
